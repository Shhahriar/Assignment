# %%
# !pip install factor_analyzer
# Out:
# Requirement already satisfied: factor_analyzer in c:\users\user\anaconda3\lib\site-packages (0.5.1)
# Requirement already satisfied: pandas in c:\users\user\anaconda3\lib\site-packages (from factor_analyzer) (2.2.2)
# Requirement already satisfied: scipy in c:\users\user\anaconda3\lib\site-packages (from factor_analyzer) (1.13.1)
# Requirement already satisfied: numpy in c:\users\user\anaconda3\lib\site-packages (from factor_analyzer) (1.26.4)
# Requirement already satisfied: scikit-learn in c:\users\user\anaconda3\lib\site-packages (from factor_analyzer) (1.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user\anaconda3\lib\site-packages (from pandas->factor_analyzer) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\anaconda3\lib\site-packages (from pandas->factor_analyzer) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user\anaconda3\lib\site-packages (from pandas->factor_analyzer) (2023.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\user\anaconda3\lib\site-packages (from scikit-learn->factor_analyzer) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\user\anaconda3\lib\site-packages (from scikit-learn->factor_analyzer) (3.5.0)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas->factor_analyzer) (1.16.0)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from factor_analyzer import FactorAnalyzer
from factor_analyzer.factor_analyzer import calculate_bartlett_sphericity, calculate_kmo

# %%
import statsmodels.api as sm
df = sm.datasets.get_rdataset("mtcars", "datasets").data
df.head()
# Out:
#                     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# rownames
# Mazda RX4          21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag      21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710         22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive     21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#                    carb
# rownames
# Mazda RX4             4
# Mazda RX4 Wag         4
# Datsun 710            1
# Hornet 4 Drive        1
# Hornet Sportabout     2

# %%
chi_square_value, p_value = calculate_bartlett_sphericity(df)
print(f"Chi-Square value: {chi_square_value:.3f}, p-value: {p_value:.3f}")
# Out:
# Chi-Square value: 408.012, p-value: 0.000

# %%
kmo_all, kmo_model = calculate_kmo(df)
print(f"KMO Model: {kmo_model:.3f}")
# Out:
# KMO Model: 0.827

# %%
fa = FactorAnalyzer(rotation="varimax")
fa.fit(df)
# Out:
# FactorAnalyzer(rotation='varimax', rotation_kwargs={})

# %%
eigen_values, vectors = fa.get_eigenvalues()
plt.scatter(range(1, df.shape[1]+1), eigen_values)
plt.plot(range(1, df.shape[1]+1), eigen_values)
plt.title('Scree Plot')
plt.xlabel('Factors')
plt.ylabel('Eigenvalue')
plt.grid()
plt.show()

# %%
fa = FactorAnalyzer(n_factors=3, rotation="varimax")
fa.fit(df)
# Out:
# FactorAnalyzer(n_factors=2, rotation='varimax', rotation_kwargs={})

# %%
loadings = pd.DataFrame(fa.loadings_, index=df.columns, columns=['Factor1', 'Factor2','Factor3'])
print(loadings)
# Out:
#        Factor1   Factor2   Factor3
# mpg   0.664678 -0.446785 -0.488240
# cyl  -0.627468  0.695738  0.282671
# disp -0.717999  0.536825  0.301686
# hp   -0.305103  0.681623  0.557019
# drat  0.806782 -0.237814 -0.063683
# wt   -0.784051  0.246917  0.481970
# qsec -0.176934 -0.933752 -0.212663
# vs    0.289355 -0.797606 -0.231490
# am    0.892181  0.106374 -0.082767
# gear  0.897917  0.005800  0.245281
# carb  0.092934  0.507064  0.774278

# %%
variance = fa.get_factor_variance()
print(variance)
# Out:
# (array([4.43566746, 3.33051272, 1.72124881]), array([0.4032425 , 0.30277388, 0.15647716]), array([0.4032425 , 0.70601638, 0.86249354]))

# %%
factor_scores = fa.transform(df) 
factor_scores_df = pd.DataFrame(factor_scores, columns=['Factor1', 'Factor2','Factor3'])
print(factor_scores_df.head())
# Out:
#     Factor1   Factor2   Factor3
# 0  0.889551  0.714905 -0.202932
# 1  0.759223  0.452291  0.037758
# 2  0.689007 -0.552857 -0.627795
# 3 -0.867423 -0.630658 -0.852553
# 4 -0.863142  0.907046 -1.007371
